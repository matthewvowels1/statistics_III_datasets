# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def generate(N):
    Ux = np.random.randn(N)
    Uy = np.random.randn(N)
    
    y = 0.3 + 0.6*Ux - 0.5*Ux**2 + Uy
    
    return y, Ux

# %%
N = 400

y, x = generate(N)

df = pd.DataFrame(data=(y,x, x**2)).T
df.columns = ['y', 'x', 'x2']
df.to_csv('quadratic.csv', index=False)

plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

print(df.head())
# Out:
#           y         x        x2
# 0 -0.018746  1.573279  2.475207
# 1  1.142497 -0.706935  0.499758
# 2 -1.348789 -0.534770  0.285979
# 3  0.716250  0.436284  0.190344
# 4 -2.334487 -2.071116  4.289520
